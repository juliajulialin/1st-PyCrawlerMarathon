# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間: ' + r.find_all(class_='article-meta-value')[3].text)
        print('\n')
    except:
        print('\n')
        continue
# Out:
# 標題: [Live] 老鷹 @ 籃網
# 作者: Rambo (香帥)
# 時間: Mon Jan 13 06:30:01 2020
#
#
# 標題: [BOX ] Jazz 127:116 Wizards 數據
#
#
# 標題: [BOX ] Heat 121:124 Knicks 數據
#
#
# 標題: [Live] 黃蜂 @ 太陽
# 作者: Rambo (香帥)
# 時間: Mon Jan 13 08:30:01 2020
#
#
# 標題: [Live] 快艇 @ 金塊
# 作者: Rambo (香帥)
# 時間: Mon Jan 13 08:30:01 2020
#
#
# 標題: [BOX ] Warriors 102:122 Grizzlies 數據
#
#
# 標題: [BOX ] Hawks 86:108 Nets 數據
#
#
# 標題: [BOX ] Spurs 105:104 Raptors 數據
#
#
# 標題: [花邊] McCollum：建議全明星賽也舉辦1v1單挑賽
# 作者: melman87 (長頸男)
# 時間: Mon Jan 13 10:03:46 2020
#
#
# 標題: [花邊] 波總講到AGG三分爆發:我教他的雙胞胎兄弟
# 作者: pneumo (超☆冒險蓋)
# 時間: Mon Jan 13 10:23:48 2020
#
#
# 標題: (已被namie刪除) <vincentgotu>nba點薄弱
#
#
# 標題: [BOX ] Hornets 92:100 Suns 數據
#
#
# 標題: [BOX ] Clippers 104:114 Nuggets 數據
#
#
# 標題: (本文已被刪除) <kayeric>
#
#
# 標題: [花邊] DeRozan在Siakam接受採訪時突然前來擁抱
# 作者: s27052705 (小飽)
# 時間: Mon Jan 13 11:36:14 2020
#
#
# 標題: [新聞] 德羅展下半場發飆 馬刺客場逆轉暴龍
# 作者: DeMarDeRozan (大媽毒龍鑽)
# 時間: Mon Jan 13 12:13:19 2020
#
#
# 標題: [情報] Irving談球隊文化：我們想成為一支冠軍級
# 作者: bbbyes123 (冬日將至)
# 時間: Mon Jan 13 12:28:50 2020
#
#
# 標題: [新聞] 哈沃德模仿詹皇賽前儀式 戴維斯賽後客串記者
# 作者: EDFR (板橋周子瑜)
# 時間: Mon Jan 13 12:56:40 2020
#
#
# 標題: [公告] 板規v6.8
#
#
# 標題: [公告] 樂透取消及未來不再開啟樂透
# 作者: Vedan (味丹)
# 時間: Mon Jun 24 15:08:02 2019
#
#
# 標題: [公告] 版主上任相關事項
# 作者: qazwsx879345 (Rajon Rondo)
# 時間: Fri Oct 25 10:44:03 2019
#
#
# 標題: [情報] SEASON Schedule 賽程 January 19–20
# 作者: Acetoxy (阿斯)
# 時間: Fri Jan  3 01:37:35 2020

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/KoreaStar/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間: ' + r.find_all(class_='article-meta-value')[3].text)
        print('\n')
    except:
        print('\n')
        continue
# Out:
# 標題: [情報] 防彈少年團JIMIN再次奪得1月男子組合個人
# 作者: xdmega (呵呵)
# 時間: Sun Jan 12 09:33:34 2020
#
#
# 標題: [新聞] 舒華自認韓文不難 神童吐槽：但聽的人很
# 作者: StressND (Plmier47kk)
# 時間: Sun Jan 12 10:23:17 2020
#
#
# 標題: [新聞] AOA澯美出道工作5年沒收入
# 作者: la1aco (lalaco)
# 時間: Sun Jan 12 12:21:04 2020
#
#
# 標題: [情報] BTS〈IDOL〉MV觀看次數破六億
# 作者: la1aco (lalaco)
# 時間: Sun Jan 12 12:31:36 2020
#
#
# 標題: [新聞] 周憲因焦慮症狀暫時停止活動
# 作者: StressND (Plmier47kk)
# 時間: Sun Jan 12 13:58:33 2020
#
#
# 標題: [新聞] 激似周子瑜！國民女友露面選舉...顏色藏
# 作者: xdmega (呵呵)
# 時間: Sun Jan 12 23:46:58 2020
#
#
# 標題: [新聞] Big Hit 收購 Pledis?!尚未決定
# 作者: haohaomin (呵)
# 時間: Mon Jan 13 09:50:15 2020
#
#
# 標題: [情報] iKON首次6人回歸倒數 MV拍攝現場公開
# 作者: LesBleus (Fansé)
# 時間: Mon Jan 13 11:07:13 2020
#
#
# 標題: [公告] 韓星板板規 (2017.06.01)
# 作者: lucard1129 (朝鮮通商大臣)
# 時間: Sun Oct 16 10:45:06 2011
#
#
# 標題: [公告] 置底 徵/讓/換 票區
# 作者: lucard1129 (朝鮮通商大臣)
# 時間: Sat May 20 20:06:11 2017
#
#
# 標題: [公告] 韓星板2018六月置底閒聊區
# 作者: lucard1129 (朝鮮通商大臣)
# 時間: Sat Jul  1 00:10:54 2017
#
#
# 標題: [公告] 調整發文權限
# 作者: zevix (　　　　　　　　　　　)
# 時間: Thu Sep 27 02:51:06 2018
#
#
# 標題: [情報] 2020年01月 來台活動/售票資訊(暫)
# 作者: orange6soda (o6s)
# 時間: Mon Jul  1 02:26:25 2019
